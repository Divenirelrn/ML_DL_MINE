# %% [markdown]
# 一元函数线性回归中，
# $$
# h = w^T + b
# $$
# 如果没有bias，最终拟合的直线是一条过原点的直线，限制了直线的搜索范围，不够灵活

# %% [markdown]
# 神经网络中，
# $$
# activation = \frac{1}{1+e^{-w^T x + b}}
# $$
# bias同样是增强神经元的拟合能力，偏置可以使激活函数沿x轴进行左右平移，从而更好地控制神经元的激活状态:
# ![image.png](attachment:image.png)
