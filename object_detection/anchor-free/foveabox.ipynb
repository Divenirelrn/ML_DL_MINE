# %% [markdown]
# foveabox发表于20年的论文"FoveaBox: Beyound Anchor-Based Object Detection"

# %% [markdown]
# foveabox结构如下图所示，直接输出cls信息与box信息。
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 文中采用了deformable conv与feature align
