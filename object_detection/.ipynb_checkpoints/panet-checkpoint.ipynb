# %% [markdown]
# panet发表于18年的论文"Path Aggregation Network for Instance Segmentation"，panet是针对于实例分割任务，同样可以迁移到物体检测领域。其历史贡献是提出路径聚合网络，缩短输入到高层特征的路径，提高定位准确性。

# %% [markdown]
# PAnet结构如下图所示，在FPN的基础上加上PAnet，提升定位准确性。同时，将mask rcnn的mask分支的fc层改为卷积层。
# ![image.png](attachment:image.png)

# %% [markdown]
# 路径聚合网络结构如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# mask分支结构如下：
# ![image.png](attachment:image.png)
