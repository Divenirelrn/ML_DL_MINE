# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 在空间曲面的一点，沿着任意方向的导数，即沿着任意方向与曲线的切线，其斜率为方向导数的值，由于方向是360度，所以这个方向是一条射线

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 梯度是一个方向，方向导数沿所有360度的方向都有值，而这360度的方向中，有一个方向就是梯度，梯度是f(x,y)增长最快的方向，也是方向导数取得最大值的方向。<br/>
# 梯度下降法中的梯度是一个向量，最后迭代式中加的梯度就是梯度本身，而不是梯度的值。
