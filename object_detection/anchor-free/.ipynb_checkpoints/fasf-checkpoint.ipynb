# %% [markdown]
# FSAF发表于19年的论文"Feature Selective Anchor-Free Module for Single-Shot Object Detection"。

# %% [markdown]
# FASF的结构如下图所示，在原有基础上添加了anchor-free的分支，
# ![image.png](attachment:image.png)

# %% [markdown]
# 根据loss自动选择anchor对应的特征层：
# ![image.png](attachment:image.png)
