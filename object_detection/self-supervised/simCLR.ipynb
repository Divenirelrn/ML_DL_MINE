# %% [markdown]
# simCLR名为"a simple framework for contrastive learning of visual representations"，与moco并成为对比学习CV双雄。simCLR的主要贡献是一些方法的组合，如添加projection层，大量的data augmentation，大batch，其中，projection层提了近10个点，被后面工作广泛使用

# %% [markdown]
# simCLR主要贡献如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# simCLR框架如下，用于下游任务时，舍弃掉h()，用的是f()
# ![image.png](attachment:image.png)

# %% [markdown]
# 伪代码如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# 对比学习相对于监督学习，需要更强的data augmentation，data augmentation主要用crop与color distortion(including color dropping, brightness, contrast, saturation,
# hue)

# %% [markdown]
# projection head用非线性的，比用线性的效果要好。

# %% [markdown]
# 大的batch-size（作者用8192）与更长的训练时间有助于对比学习。
