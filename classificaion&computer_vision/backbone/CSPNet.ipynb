# %% [markdown]
# CSPNet发表于2019年的论文"CSPNET: A NEW BACKBONE THAT CAN ENHANCE LEARNING
# CAPABILITY OF CNN"，文中提出了一种cross-stage的方式来对resnet、densenet等网络进行改进，在保持甚至提升精度的基础上，减少内存消耗量与推理时间。同时，作者还提出一种新的特征融合策略EFM.

# %% [markdown]
# CSPDenseNet的整体结构如下，将输入特征图分为两部分，一部分经过denseblock后进行transition操作，另一部分与transition的特征图相连，再进行一次transition操作。
# ![image.png](attachment:image.png)

# %% [markdown]
# cspnet的意义在于减少重复梯度，如下图densenet的前向与反向传播：
# ![image.png](attachment:image.png)

# %% [markdown]
# 在cspdensenet中，梯度是分开传递的，可以减少重复梯度信息
# ![image.png](attachment:image.png)

# %% [markdown]
# 在partial dense block的设计上，有以下几种方式，作者采用了(b)的方式：
# ![image.png](attachment:image.png)

# %% [markdown]
# 此外，在特征融合方面，作者提出EFM:
# ![image.png](attachment:image.png)
