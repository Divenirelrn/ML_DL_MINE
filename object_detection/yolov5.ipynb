# %% [markdown]
# yolov5并没有论文，是引入一些创新点对yolo的改进，达到与yolov4近似的效果，但在模型选择上更加灵活。

# %% [markdown]
# 自适应图像缩放<br/>
# 保持长宽比，填充最少黑边，达到优化推理速度的效果
# ![image.png](attachment:image.png)

# %% [markdown]
# Focus结构<br/>
# 主要是切片操作，降低特征图尺寸，提高训练速度
# ![image.png](attachment:image.png)

# %% [markdown]
# 网络结构<br/>
# yolov5包括s,m,l,x,l6,x6等结构，可以根据需要进行结构选择
