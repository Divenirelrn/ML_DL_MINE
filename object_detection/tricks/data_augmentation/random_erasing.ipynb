# %% [markdown]
# random reasing发表自2017年的论文"Random Erasing Data Augmentation"，文中提出一种数据集扩增的方法，对输入图像随机擦除一块矩形区域，用随机值填充，这样有效提升了模型的泛化能力以及精度。

# %% [markdown]
# random erasing的方法如下图所示：
# ![image.png](attachment:image.png)

# %% [markdown]
# random erasing的算法流程如下图所示，需要调节的参数包括random erasing发生的概率、图像宽高、擦除区域面积范围、擦除区域长宽比范围
# ![image.png](attachment:image.png)

# %% [markdown]
# 对于目标检测来说，随机擦除包括image-aware,object-aware,both of them
# ![image.png](attachment:image.png)

# %% [markdown]
# random erasing与random crop、random flip不互斥，三者联合能达到更好的效果：
# ![image.png](attachment:image.png)
