# %% [markdown]
# centernet发表于19年的论文"CenterNet: Keypoint Triplets for Object Detection".

# %% [markdown]
# centernet结构如下，在cornernet基础上加入center heamap，并且加入center pooing，将corner pooing改为cascade corner pooling
# ![image.png](attachment:image.png)

# %% [markdown]
# gt中positive定义如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# center pooling结构如下：
# ![image.png](attachment:image.png)
