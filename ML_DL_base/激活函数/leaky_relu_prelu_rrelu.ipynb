# %% [markdown]
# leaky_relu的数学形式为：
# $$
# f(x) =
#  \begin{cases}
#  x, x>=0\\
#  0.01x, x<0
#  \end{cases}
# $$

# %% [markdown]
# 函数图像为：
# ![image.png](attachment:image.png)

# %% [markdown]
# 优点：解决了relu的死亡神经元问题

# %% [markdown]
# prelu(parametric relu)是将leaky relu的参数0.01变为一个可通过梯度下降算法学习的参数

# %% [markdown]
# rrelu(randomized relu)是在训练阶段在一个均匀分布里采样得到$\alpha$的值（每一个mini-batch），在测试阶段是固定的
