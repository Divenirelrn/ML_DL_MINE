# %% [markdown]
# DETR发表于20年的论文"End-to-End Object Detection with Transformers"，首次将transformer应用于object detection，取得了能够与传统目标检测相似的效果，但训练过程非常缓慢。

# %% [markdown]
# DETR将CNN与transformer相结合，直接用transformer输出检测结果。
# ![image.png](attachment:image.png)

# %% [markdown]
# 具体结构如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# DETR用的是NAT结构，decoder的输入为N，N为远大于图像中目标数量的数字，输出的检测目标同样为N，没有物体的目标为$\Phi$，即没有物体。输入与输出一一对应，采用匈牙利算法实现（？）。

# %% [markdown]
# 损失函数Hungarian loss如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# $其中，\hat \delta(i)由下式计算：$
# ![image.png](attachment:image.png)

# %% [markdown]
# $L_{match}形式如下：$
# ![image.png](attachment:image.png)

# %% [markdown]
# $L{box}结构如下：$
# ![image.png](attachment:image.png)
