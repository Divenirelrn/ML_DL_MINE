# %% [markdown]
# L1正则化与L2正则化的表达式如下：
# $$
# \min_w L = \min_w\frac{1}{2m}\sum_{i=1}^{m}{(y_i - f(x_i))^2} + \lambda\sum_{i=1}^{m}{|w|} （L1正则化） \\
# \min_w L = \min_w\frac{1}{2m}\sum_{i=1}^{m}{(y_i - f(x_i))^2} + \lambda \sum_{i=1}^{m}{w^2}（L2正则化）
# $$

# %% [markdown]
# 用L1正则化与L2正则化相当于给解空间做了限制，如下图所示（假设参数个数为2），图中的交点即为最优解：
# ![image.png](attachment:image.png)

# %% [markdown]
# L1正则化的解空间如左图菱形所示，目标函数的等值线更容易与菱形的顶点相交，交点处某些参数值为0，因此L1正则化具有参数稀疏、特征选择作用<br/>
# L2正则化的解空间如右图圆形所示，目标函数的等值线更容易与圆形的某个点相切，因此L2是对参数的取值做限制（使取值限制在一定范围内）
