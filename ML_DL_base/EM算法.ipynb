# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# $其中，P(Z|Y, \theta^{(i)})表示z取某个值的概率（如抛硬币问题中，表示z=A的概率或z=B的概率）；P(Y,z|\theta)表示当z取某个值时，当前观测值的概率（如抛硬币问题，假设某次实验结果为正，正，负，正，负，z=A时，P(Y,z|\theta)=P(Y,A|\theta)=\theta_A^3*(1-\theta_A)^2）$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
