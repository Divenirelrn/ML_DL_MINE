# %% [markdown]
# fcos发表于19年的论文"FCOS: Fully Convolutional One-Stage Object Detection"。

# %% [markdown]
# fcos的结构如下图所示
# ![image.png](attachment:image.png)

# %% [markdown]
# 其中centerness分支用于抑制低质量的框，每个输出的score乘以centerness，离中心点越远则centerness越小，低质量框的score得到抑制，最终通过nms将其去除。
# ![image.png](attachment:image.png)

# %% [markdown]
# centerness如下图所示：
# ![image.png](attachment:image.png)

# %% [markdown]
# loss函数如下：
# ![image.png](attachment:image.png)
