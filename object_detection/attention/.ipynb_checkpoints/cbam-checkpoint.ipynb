# %% [markdown]
# cbam模块发表于18年的论文"CBAM: Convolutional Block Attention Module"，同样是一种混合注意力机制，可以嵌入到现有网络架构。

# %% [markdown]
# cbam结构图如下所示，由通道注意力模块与空间注意力模块串联而成。通道注意力模块关注于"what is meaningful"（每个channel学习不同的特征），空间注意力模块关注于"where is meaningful"
# ![image.png](attachment:image.png)

# %% [markdown]
# 其公式如下：
# ![image.png](attachment:image.png)
# $其中，F为输入特征图$

# %% [markdown]
# 通道注意力与空间注意力子模块如下图所示。
# ![image.png](attachment:image.png)

# %% [markdown]
# 通道注意力公式如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# 空间注意力公式如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# 此外，作者设计了一个residual结构，如下：
# ![image.png](attachment:image.png)
