# %% [markdown]
# cutout出自17年发表的论文"Improved Regularization of Convolutional Neural Networks with Cutout"，提出一种新的数据集扩增方式，与random erasing类似，但mask是方形的，mask的值是固定的。

# %% [markdown]
# cotout的实现方式见下图，对于原始的图像，随机用一个方形区域覆盖，迫使网络更多关注全局信息，而不是局部信息。
# ![image.png](attachment:image.png)

# %% [markdown]
# 初始版本的cutout如下，随机覆盖原图像的部件：
# ![image.png](attachment:image.png)

# %% [markdown]
# 作者发现mask的尺寸更重要，而不是shape，因此统一用方形mask。

# %% [markdown]
# 对于mask的尺寸，作者用grid search来搜索最优参数：
# ![image.png](attachment:image.png)

# %% [markdown]
# cutout与其他数据集扩增方法并不矛盾，可以联合使用。

# %% [markdown]
# 此外，作者发现，令mask有一部分在图像以外，对取得好的结果有重要影响。
