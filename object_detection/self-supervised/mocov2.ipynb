# %% [markdown]
# mocov2将simCLR的两个创新点引入moco，对moco进行了升级，达到了优于moco v1与simclr的效果，两个创新点分别是nonlinear projection，more data augmentation
# ![image.png](attachment:image.png)

# %% [markdown]
# 主要结果如下：
# ![image.png](attachment:image.png)
