# %% [markdown]
# 标题：
# ![image.png](attachment:image.png)

# %% [markdown]
# 文中提到，Transformer相对于卷积网络来说，缺乏了一些先验知识，如局部性与平移等价性，但在大规模数据集上进行预训练，transformer的表现不输于甚至优于卷积

# %% [markdown]
# vit的整体架构如下,cls_token是仿照bert的方法，最后分类head只对cls_token的激活值产生输出
# ![image.png](attachment:image.png)

# %% [markdown]
# 关键公式如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# 与CNN的对比：
# ![image.png](attachment:image.png)
