# %% [markdown]
# warmup首发于2017年的论文"SGDR: STOCHASTIC GRADIENT DESCENT WITH
# WARM RESTARTS"，一般与cosine decay联合使用，首先在前几个epoch将学习率增长为较大值，然后利用cosine anealing衰减至最小值。

# %% [markdown]
# warmup restart是一种周期性的过程，与multistep decay对比如下：
# ![image.png](attachment:image.png)
