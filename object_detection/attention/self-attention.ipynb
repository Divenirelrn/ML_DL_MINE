# %% [markdown]
# self-attention模块结构如下，4个输入对应4个输出：
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# multi-head self-attention结构如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# position encoding:
# ![image.png](attachment:image.png)
