# %%
import torch
import torch.nn as nn

#without learnable parameters
m = nn.InstanceNorm2d(100)
#with learnable parameters
# m = nn.InstaceNorm2d(affine=True)
input = torch.randn(20, 100, 35, 45)
print(m(input))
# Out:
# tensor([[[[-6.2351e-01, -1.0256e+00, -2.7616e-01,  ..., -4.6649e-01,
#             8.3408e-01, -2.3205e+00],
#           [-5.2011e-01,  5.9608e-01,  7.9216e-01,  ...,  1.3291e-01,
#             1.1454e-01, -2.1388e-01],
#           [ 1.3316e+00,  5.6759e-01,  1.2784e+00,  ..., -8.1592e-01,
#             3.2709e+00, -8.5475e-01],
#           ...,
#           [-1.1516e-01,  4.6243e-01,  8.9870e-01,  ..., -6.2671e-01,
#            -5.2175e-01,  1.7060e+00],
#           [ 1.0182e+00, -6.6475e-01,  5.0491e-01,  ...,  1.0841e+00,
#             3.3965e-01, -6.7048e-01],
#           [ 1.2630e-01,  3.7901e-01,  2.5432e+00,  ...,  2.3812e-01,
#            -1.1000e+00,  1.0273e+00]],
#
#          [[ 1.6469e+00,  2.5734e-01,  5.2363e-01,  ...,  1.9769e-01,
#             4.0065e-01,  1.7334e+00],
#           [ 2.1144e-01, -2.2729e+00,  6.6483e-02,  ...,  1.5049e+00,
#            -1.3186e+00,  3.7622e-02],
#           [ 9.6832e-01, -5.9539e-01, -8.9130e-01,  ...,  3.7053e-01,
# ...
