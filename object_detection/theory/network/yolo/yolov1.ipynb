# %% [markdown]
# 网络结构：
# ![image.png](attachment:image.png)

# %% [markdown]
# 流程：
# ![image.png](attachment:image.png)

# %% [markdown]
# cost function:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
