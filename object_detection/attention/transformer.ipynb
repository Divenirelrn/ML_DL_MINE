# %% [markdown]
# transformer整体结构如下，由encoder与decoder组成。encoder与decoder均是基于self-attention结构构建。
# ![image.png](attachment:image.png)

# %% [markdown]
# encoder结构如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# decoder与encoder结构基本一致，差别在于cross attention，即下图被遮挡部分：
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# AT(autogressive)与NAT(non-autogressive):
# ![image.png](attachment:image.png)
