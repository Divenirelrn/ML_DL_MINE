# %% [markdown]
# mish的数学形式为：
# $$
# f(x) = xtanh(softplus(x)) = xtanh(ln(1 + e^x))
# $$

# %% [markdown]
# 图像为：
# ![image.png](attachment:image.png)

# %% [markdown]
# mish函数的提出也是受到了swish函数中门控单元的启发，对于门控单元，作者试凑了诸如$arctan(x)softplus(x)、tanh(x)softplus(x)、xlog(1+arctan(e^x))等形式，最后采用了精度最高的tanh(softplus)形式$

# %% [markdown]
# mish比swish优秀的原理难以讲清楚，作者也是从无上界、有下界、非单调、平滑性等方面来阐释mish的优点，对于平滑性，作者给出了不同激活函数的loss曲面：
# ![image.png](attachment:image.png)
