# %% [markdown]
# non-local发表于18年的论文"Non-local Neural Networks"，其历史贡献是将自注意力机制引入视觉领域。

# %% [markdown]
# non-local模块结构如下图所示（\theta与\phi代表self-attention中的q,k，g对应于v）：
# ![image.png](attachment:image.png)

# %% [markdown]
# 公式如下：
# ![image.png](attachment:image.png)
# $其中f(x_i, x_j)为上图\theta与\phi计算的特征相似性，C(x)为归一化因子。$

# %% [markdown]
# $f(x_i,x_j)的形式有以下几种形式：$<br/>
# 1）高斯函数
# ![image.png](attachment:image.png)

# %% [markdown]
# 2)embedded Gaussian:<br/>
# ![image.png](attachment:image.png)

# %% [markdown]
# 3)dot product
# ![image.png](attachment:image.png)

# %% [markdown]
# 4)concatenation
# ![image.png](attachment:image.png)
